# %%
import pandas as pd

path =  './sat.txt'
read_file = pd.read_csv("./sat.txt")
read_file.to_csv('./sat.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[3], line 5
#       3 path =  './sat.txt'
#       4 read_file = pd.read_csv("./sat.txt")
# ----> 5 read_file.to_csv('./sat.csv', index=False)
#       6 data = pd.read_csv("./sat.csv")
#
# File c:\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
data = pd.read_csv("./sat.csv")

# %%
import statsmodels.formula.api as smf

model = smf.ols('expend ~ predictors+ratio+salary+takers+total', data = data).fit() # Fit the model
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File c:\Python312\Lib\site-packages\patsy\compat.py:36, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35 try:
# ---> 36     return f(*args, **kwargs)
#      37 except Exception as e:
#
# File c:\Python312\Lib\site-packages\patsy\eval.py:169, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     168 code = compile(expr, source_name, "eval", self.flags, False)
# --> 169 return eval(code, {}, VarLookupDict([inner_namespace]
#     170                                     + self._namespaces))
#
# File <string>:1
#
# NameError: name 'takers' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 import statsmodels.formula.api as smf
# ...
