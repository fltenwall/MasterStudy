# %%
import numpy as np

array_15_by_10_by_20 = np.random.uniform(0, 1, size=(1000, 1000, 1000))
 
print(array_15_by_10_by_20)
# Out:
# [[[6.02219382e-01 3.30100473e-02 7.36738811e-01 ... 5.34239135e-02
#    2.37029265e-01 8.80570237e-02]
#   [6.66504026e-03 7.72494823e-01 1.06534144e-01 ... 8.91811770e-01
#    7.16925418e-01 5.12028564e-01]
#   [9.43200184e-01 4.27942788e-01 7.99870771e-02 ... 6.24831911e-01
#    6.92906513e-01 5.55204570e-01]
#   ...
#   [7.58963772e-01 6.93874836e-01 9.69690178e-01 ... 4.47991213e-02
#    1.38697972e-01 8.09359579e-01]
#   [6.27354699e-01 1.17179899e-01 5.12411719e-01 ... 3.88698139e-01
#    9.86621433e-01 3.75651527e-01]
#   [1.45046801e-01 8.98374598e-01 5.35600442e-01 ... 7.16464019e-01
#    5.09821947e-01 5.59884994e-01]]
#
#  [[1.47602124e-01 9.79906371e-01 9.92934086e-01 ... 4.68608872e-01
#    8.64160206e-01 2.87211822e-01]
#   [4.49976913e-01 8.85362175e-01 6.69440733e-02 ... 9.69114021e-01
#    3.72799999e-01 4.99394189e-01]
#   [6.52510964e-01 4.48888491e-01 5.53262902e-01 ... 2.87119589e-01
#    6.96819014e-01 6.52092655e-01]
#   ...
# ...

# %%
len(array_15_by_10_by_20[0])
# Out:
# 1000

# %%
len(array_15_by_10_by_20[999])
# Out:
# 1000

# %%
len(array_15_by_10_by_20[0][0])
# Out:
# 1000

# %%
item_count = 1000
select_list = []
count = 0
first_level_random_used = set()
second_level_random_used = set()

while True:
    first_level_random = np.random.randint(1, 1000)
    second_level_random = np.random.randint(1, 1000)
    
    while first_level_random not in first_level_random_used:
        first_level_random_used.add(first_level_random)
        break
    while second_level_random not in second_level_random_used:
        second_level_random_used.add(second_level_random)
        break
    
    for second_array in array_15_by_10_by_20[first_level_random]:
        second_array_mean = np.mean(array_15_by_10_by_20[second_level_random])
        for item in second_array:
            if item > second_array_mean:
                count = count + 1
                select_list.append(item)
            if count >= item_count:
                break
        if count >= item_count:
                break
    if count >= item_count:
                break
print(select_list)
print(len(select_list))
print(np.sum(np.array(select_list)))
# Out:
# [0.7866199155020299, 0.9124328313308309, 0.5397833284110367, 0.5266372505832517, 0.6062398197929243, 0.8939412757900213, 0.5172003065071266, 0.7412399329901829, 0.7224205521674164, 0.6384813999598775, 0.7815925379379938, 0.7247310660130685, 0.9745419766022434, 0.9675893611183869, 0.5571523228944982, 0.6059282515720538, 0.7001811669412301, 0.9710146006353845, 0.6411341508734655, 0.85408120122534, 0.9935546301909114, 0.9943784125620364, 0.9198602875155322, 0.7763810544645278, 0.7160451721267486, 0.7788312451376798, 0.632182609741181, 0.6259889966288131, 0.9488364402277647, 0.5160565446895116, 0.5543599389822057, 0.5586213424293502, 0.7797658799025992, 0.9955164094580352, 0.5283317717764643, 0.964006837933062, 0.8796421520280846, 0.7325608477095281, 0.9365258278200863, 0.8379975666081225, 0.6946417237735432, 0.67172902931024, 0.9113217623491651, 0.9803322187612634, 0.8997440421600887, 0.9682544898974704, 0.7802758874898539, 0.7254889703128892, 0.9193240406859419, 0.7099955141345663, 0.8
# ...

# %%
xxxxxxx
